# %% [markdown]
# # Índice <a name="Contents"></a>
# 1. [Importando bibliotecas](#import)
# 2. [Construindo um dataframe](#read)
# 3. [Renomeando colunas](#colunas)
# 4. [Renomeando índices](#indices)

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import pandas as pd
import numpy  as np

# %% [markdown]
# # 2. Construindo um dataframe <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
df = pd.DataFrame(
    np.random.randn(9, 4)*100,
    index=["A", "B", "C", "D", "E", "F", "G", "H", "I"],
    columns=["coluna1", "coluna2", "coluna3","coluna4"],
)
df
# Out:
#       coluna1     coluna2     coluna3     coluna4
# A  157.361461  -47.724013  -39.738770  -70.927450
# B  -79.778569  -21.314715  -25.950323    5.327168
# C  196.808092   -4.588883  -36.353946  173.954257
# D -139.403788 -110.772708  -35.659909  -63.891390
# E   -1.146116    4.586482 -122.621869  129.422925
# F  -66.732970 -119.971594  -82.297405  170.962265
# G   53.772757  103.234673  -97.229803 -216.822152
# H  202.333459 -127.829524   93.895480   12.208832
# I -194.380580  134.104123   -5.187491  -28.605721

# %% [markdown]
# # 3. Renomeando colunas <a name="colunas"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
df.columns
# Out:
# Index(['coluna1', 'coluna2', 'coluna3', 'coluna4'], dtype='object')

# %%
df.columns = ['segunda', 'terça', 'quarta', 'quinta']

# %%
df.columns
# Out:
# Index(['segunda', 'terça', 'quarta', 'quinta'], dtype='object')

# %%
df
# Out:
#       segunda       terça      quarta      quinta
# A  157.361461  -47.724013  -39.738770  -70.927450
# B  -79.778569  -21.314715  -25.950323    5.327168
# C  196.808092   -4.588883  -36.353946  173.954257
# D -139.403788 -110.772708  -35.659909  -63.891390
# E   -1.146116    4.586482 -122.621869  129.422925
# F  -66.732970 -119.971594  -82.297405  170.962265
# G   53.772757  103.234673  -97.229803 -216.822152
# H  202.333459 -127.829524   93.895480   12.208832
# I -194.380580  134.104123   -5.187491  -28.605721

# %% [markdown]
# # 4. Renomeando índices <a name="indices"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
df['coluna5'] = ['letraA','letraB','letraC','letraD','letraE','letraF','letraG','letraH','letraI']

# %%
df
# Out:
#       segunda       terça      quarta      quinta coluna5
# A  157.361461  -47.724013  -39.738770  -70.927450  letraA
# B  -79.778569  -21.314715  -25.950323    5.327168  letraB
# C  196.808092   -4.588883  -36.353946  173.954257  letraC
# D -139.403788 -110.772708  -35.659909  -63.891390  letraD
# E   -1.146116    4.586482 -122.621869  129.422925  letraE
# F  -66.732970 -119.971594  -82.297405  170.962265  letraF
# G   53.772757  103.234673  -97.229803 -216.822152  letraG
# H  202.333459 -127.829524   93.895480   12.208832  letraH
# I -194.380580  134.104123   -5.187491  -28.605721  letraI

# %%
df.set_index('coluna5')
