# %%
import numpy  as np
import pandas as pd

# %% [markdown]
# # Operações com ``DataFrame``

# %% [markdown]
# ## Criando 2 dataframes (3 x 5)

# %%
np.random.randint(10, size=(3, 5))
# Out:
# array([[2, 4, 3, 5, 6],
#        [3, 6, 5, 0, 7],
#        [5, 5, 5, 4, 9]])

# %%
df1 = pd.DataFrame(np.random.randint(10, size=(3, 5)), columns=['A','B','C','D','E'])
df1
# Out:
#    A  B  C  D  E
# 0  2  2  2  5  8
# 1  8  2  8  3  8
# 2  2  1  0  9  0

# %%
df2 = pd.DataFrame(np.random.randint(10, size=(3, 5)), columns=['A','B','C','D','E'])
df2
# Out:
#    A  B  C  D  E
# 0  4  1  6  5  9
# 1  2  0  9  1  8
# 2  5  4  7  0  0

# %% [markdown]
# ## Somando 2 dataframes (3 x 5)

# %%
#soma elemento a elemento
df1 + df2
# Out:
#     A  B   C   D   E
# 0   6  3   8  10  17
# 1  10  2  17   4  16
# 2   7  5   7   9   0

# %% [markdown]
# ## Criando 1 dataframe (1 x 5)

# %%
df3 = pd.DataFrame(np.random.randint(10, size=(1, 5)), columns=['A','B','C','D','E'])
df3
# Out:
#    A  B  C  D  E
# 0  8  1  9  6  7

# %% [markdown]
# ## Somando 2 dataframes (3 x 5 e 1 x 5)

# %%
df1 + df3
# Out:
#       A    B     C     D     E
# 0  10.0  3.0  11.0  11.0  15.0
# 1   NaN  NaN   NaN   NaN   NaN
# 2   NaN  NaN   NaN   NaN   NaN

# %% [markdown]
# ## Zerando uma linha

# %%
df1
# Out:
#    A  B  C  D  E
# 0  5  1  4  0  3
# 1  4  7  0  8  8
# 2  7  7  7  0  5

# %%
df1.iloc[0]
# Out:
# A    2
# B    2
# C    2
# D    5
# E    8
# Name: 0, dtype: int32

# %%
df1 - df1.iloc[0]
# Out:
#    A  B  C  D  E
# 0  0  0  0  0  0
# 1  6  0  6 -2  0
# 2  0 -1 -2  4 -8

# %% [markdown]
# ## Operação com escalar

# %%
df1
# Out:
#    A  B  C  D  E
# 0  2  2  2  5  8
# 1  8  2  8  3  8
# 2  2  1  0  9  0

# %%
df1 * 100
# Out:
#      A    B    C    D    E
# 0  500  100  400    0  300
# 1  400  700    0  800  800
# 2  700  700  700    0  500

# %%
df1 * 100 + 200
# Out:
#      A    B    C     D     E
# 0  700  300  600   200   500
# 1  600  900  200  1000  1000
# 2  900  900  900   200   700

# %% [markdown]
# ## Transpondo df

# %%
df1
# Out:
#    A  B  C  D  E
# 0  5  1  4  0  3
# 1  4  7  0  8  8
# 2  7  7  7  0  5

# %%
df1.T
# Out:
#    0  1  2
# A  5  4  7
# B  1  7  7
# C  4  0  7
# D  0  8  0
# E  3  8  5

# %% [markdown]
# ## Calculando exponencial dos valores

# %%
np.exp(df1)
# Out:
#              A         B            C            D            E
# 0     7.389056  7.389056     7.389056   148.413159  2980.957987
# 1  2980.957987  7.389056  2980.957987    20.085537  2980.957987
# 2     7.389056  2.718282     1.000000  8103.083928     1.000000

# %% [markdown]
# # Registros de Vacinação COVID19 (Acre)
#
# link: https://opendatasus.saude.gov.br/dataset/covid-19-vacinacao/resource/ef3bd0b8-b605-474b-9ae5-c97390c197a8

# %% [markdown]
# ## Lendo CSV

# %%
vacAcre = pd.read_csv(
    'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-a9fb997b-9ec9-400f-9588-d08519d6aa35.c000.csv',
    sep=';')
vacAcre
# Out:
# C:\Users\55119\AppData\Local\Temp\ipykernel_1984\1760941279.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   vacAcre = pd.read_csv(
#                                       document_id  \
# 0       c5ec44e8-a007-43c3-93d1-45125a6a2548-i0b0
# 1       8a962569-8693-4c30-866f-4d3fba14a686-i0b0
# 2       fb5df3d7-a372-4ff1-a346-01963be6e51c-i0b0
# 3       8aacaae0-8920-4733-9824-8ca22147c6b9-i0b0
# 4       c4fe1c06-9d03-4fb3-9f09-d03ae04172ed-i0b0
# ...                                           ...
# 351490  110fd193-0ad9-4ce2-a8fe-86b5172717be-i0b0
# 351491  1121b9a2-e1ed-4bee-bb46-def2b5efe968-i0b0
# 351492  1133774d-2d23-49c1-9bca-6047e199658d-i0b0
# 351493  1137d9c9-eea4-46cb-bb67-84d3c9e43ff6-i0b0
# 351494  116132d2-40c8-4b4e-959a-a7e6b26dcb54-i0b0
#
#                                               paciente_id  paciente_idade  \
# 0       27ee28eed45c4a09ef3a63f87dec8d43ed5c95812d7c31...              19
# 1       6f7639d85ae7378350820fc380218065678f2b8c6afae6...              29
# 2       a32b116a1c8cfab56a0e4c972c35289d89ea9995ed89c5...              40
# 3       bd90a92321a8c2899e9fd1ed54f2a72f3d485ca0cba91c...              12
# 4       b04dc8dc9a414410e7defb82eedd78ffeba9326ffe2a5e...              14
# ...                                                   ...             ...
# 351490  8dd1eab7ed223aca0765edf5926505f7f1d7d319de9f51...              27
# 351491  93369c04cc09cc9619418b43b52278d1342bc41c671fd8...              35
# 351492  4da373edd2740c2a8885ea711cfdfb61b214de289b71c3...              17
# 351493  dde0ba9e2ca55c330437c9c81208a1e9a47e87158b7fcb...              42
# 351494  3d34dc6b4fb6d4ff45e3d1842ebdb2f14f44d237b9c1ee...              24
#
#        paciente_dataNascimento paciente_enumSexoBiologico  \
# 0                   2002-05-08                          F
# 1                   1992-06-21                          M
# 2                   1980-10-06                          F
# 3                   2010-03-01                          M
# 4                   2007-04-05                          F
# ...                        ...                        ...
# 351490              1994-04-01                          F
# 351491              1986-01-28                          F
# 351492              2004-03-15                          F
# 351493              1978-12-30                          M
# 351494              1996-11-22                          F
#
#         paciente_racaCor_codigo paciente_racaCor_valor  \
# 0                            99         SEM INFORMACAO
# 1                            99         SEM INFORMACAO
# 2                             3                  PARDA
# 3                             5               INDIGENA
# 4                            99         SEM INFORMACAO
# ...                         ...                    ...
# 351490                        3                  PARDA
# 351491                        3                  PARDA
# 351492                        4                AMARELA
# 351493                        3                  PARDA
# 351494                        3                  PARDA
#
#        paciente_endereco_coIbgeMunicipio paciente_endereco_coPais  \
# 0                               120040.0                     10.0
# 1                               120032.0                     10.0
# 2                               120040.0                     10.0
# 3                               120043.0                     10.0
# 4                               120040.0                     10.0
# ...                                  ...                      ...
# 351490                            120040                     10.0
# 351491                            120040                     10.0
# 351492                            120050                     10.0
# 351493                            120034                     10.0
# 351494                            120025                     10.0
#
#        paciente_endereco_nmMunicipio  ... vacina_categoria_codigo  \
# 0                         RIO BRANCO  ...                     2.0
# 1                             JORDAO  ...                     2.0
# 2                         RIO BRANCO  ...                     9.0
# 3                SANTA ROSA DO PURUS  ...                     7.0
# 4                         RIO BRANCO  ...                     2.0
# ...                              ...  ...                     ...
# 351490                    RIO BRANCO  ...                     2.0
# 351491                    RIO BRANCO  ...                     1.0
# 351492                SENA MADUREIRA  ...                     2.0
# 351493                 MANOEL URBANO  ...                     2.0
# 351494                EPITACIOLANDIA  ...                     2.0
#
#          vacina_categoria_nome vacina_lote vacina_fabricante_nome  \
# 0                 Faixa Etária      FA9096                 PFIZER
# 1                 Faixa Etária  215VCD134Z    ASTRAZENECA/FIOCRUZ
# 2       Trabalhadores de Saúde   202010040       SINOVAC/BUTANTAN
# 3              Povos Indígenas      FP8073                 PFIZER
# 4                 Faixa Etária      FA9096                 PFIZER
# ...                        ...         ...                    ...
# 351490            Faixa Etária      FF8848                 PFIZER
# 351491            Comorbidades      EX2405                 PFIZER
# 351492            Faixa Etária      FF8840                 PFIZER
# 351493            Faixa Etária  217VCD227Z    ASTRAZENECA/FIOCRUZ
# 351494            Faixa Etária  215VCD116W    ASTRAZENECA/FIOCRUZ
#
#         vacina_fabricante_referencia vacina_dataAplicacao  \
# 0        Organization/00394544000851           2021-07-23
# 1        Organization/33781055000135           2021-07-21
# 2        Organization/61189445000156           2021-02-24
# 3                 Organization/28290           2022-03-28
# 4        Organization/00394544000851           2021-08-11
# ...                              ...                  ...
# 351490            Organization/28290           2022-02-22
# 351491   Organization/00394544000851           2021-05-15
# 351492   Organization/00394544000851           2021-10-06
# 351493   Organization/33781055000135           2021-08-31
# 351494   Organization/33781055000135           2021-07-06
#
#        vacina_descricao_dose  vacina_codigo  \
# 0                    1ª Dose             87
# 1                    1ª Dose             85
# 2                    2ª Dose             86
# 3                    1ª Dose             87
# 4                    1ª Dose             87
# ...                      ...            ...
# 351490               1ª Dose             87
# 351491               1ª Dose             87
# 351492               2ª Dose             87
# 351493               2ª Dose             85
# 351494               1ª Dose             85
#
#                                       vacina_nome sistema_origem
# 0                     COVID-19 PFIZER - COMIRNATY       Novo PNI
# 1       COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 2           COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# 3                     COVID-19 PFIZER - COMIRNATY       Novo PNI
# 4                     COVID-19 PFIZER - COMIRNATY       Novo PNI
# ...                                           ...            ...
# 351490                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 351491                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 351492                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 351493  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 351494  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
#
# [351495 rows x 32 columns]

# %%
vacAcre.head()
# Out:
#                                  document_id  \
# 0  c5ec44e8-a007-43c3-93d1-45125a6a2548-i0b0
# 1  8a962569-8693-4c30-866f-4d3fba14a686-i0b0
# 2  fb5df3d7-a372-4ff1-a346-01963be6e51c-i0b0
# 3  8aacaae0-8920-4733-9824-8ca22147c6b9-i0b0
# 4  c4fe1c06-9d03-4fb3-9f09-d03ae04172ed-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  27ee28eed45c4a09ef3a63f87dec8d43ed5c95812d7c31...              19
# 1  6f7639d85ae7378350820fc380218065678f2b8c6afae6...              29
# 2  a32b116a1c8cfab56a0e4c972c35289d89ea9995ed89c5...              40
# 3  bd90a92321a8c2899e9fd1ed54f2a72f3d485ca0cba91c...              12
# 4  b04dc8dc9a414410e7defb82eedd78ffeba9326ffe2a5e...              14
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              2002-05-08                          F                       99
# 1              1992-06-21                          M                       99
# 2              1980-10-06                          F                        3
# 3              2010-03-01                          M                        5
# 4              2007-04-05                          F                       99
#
#   paciente_racaCor_valor paciente_endereco_coIbgeMunicipio  \
# 0         SEM INFORMACAO                          120040.0
# 1         SEM INFORMACAO                          120032.0
# 2                  PARDA                          120040.0
# 3               INDIGENA                          120043.0
# 4         SEM INFORMACAO                          120040.0
#
#   paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                     10.0                    RIO BRANCO  ...
# 1                     10.0                        JORDAO  ...
# 2                     10.0                    RIO BRANCO  ...
# 3                     10.0           SANTA ROSA DO PURUS  ...
# 4                     10.0                    RIO BRANCO  ...
#
#   vacina_categoria_codigo   vacina_categoria_nome vacina_lote  \
# 0                     2.0            Faixa Etária      FA9096
# 1                     2.0            Faixa Etária  215VCD134Z
# 2                     9.0  Trabalhadores de Saúde   202010040
# 3                     7.0         Povos Indígenas      FP8073
# 4                     2.0            Faixa Etária      FA9096
#
#   vacina_fabricante_nome  vacina_fabricante_referencia vacina_dataAplicacao  \
# 0                 PFIZER   Organization/00394544000851           2021-07-23
# 1    ASTRAZENECA/FIOCRUZ   Organization/33781055000135           2021-07-21
# 2       SINOVAC/BUTANTAN   Organization/61189445000156           2021-02-24
# 3                 PFIZER            Organization/28290           2022-03-28
# 4                 PFIZER   Organization/00394544000851           2021-08-11
#
#   vacina_descricao_dose  vacina_codigo  \
# 0               1ª Dose             87
# 1               1ª Dose             85
# 2               2ª Dose             86
# 3               1ª Dose             87
# 4               1ª Dose             87
#
#                                  vacina_nome sistema_origem
# 0                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 1  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 2      COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# 3                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 4                COVID-19 PFIZER - COMIRNATY       Novo PNI
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Verificando dataframe

# %%
vacAcre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351495 entries, 0 to 351494
# Data columns (total 32 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   document_id                               351495 non-null  object
#  1   paciente_id                               351495 non-null  object
#  2   paciente_idade                            351495 non-null  int64
#  3   paciente_dataNascimento                   351495 non-null  object
#  4   paciente_enumSexoBiologico                351495 non-null  object
#  5   paciente_racaCor_codigo                   351495 non-null  int64
#  6   paciente_racaCor_valor                    351495 non-null  object
#  7   paciente_endereco_coIbgeMunicipio         349350 non-null  object
#  8   paciente_endereco_coPais                  349354 non-null  object
#  9   paciente_endereco_nmMunicipio             349353 non-null  object
#  10  paciente_endereco_nmPais                  349354 non-null  object
#  11  paciente_endereco_uf                      349350 non-null  object
#  12  paciente_endereco_cep                     316706 non-null  object
#  13  paciente_nacionalidade_enumNacionalidade  351363 non-null  object
#  14  estabelecimento_valor                     351495 non-null  int64
#  15  estabelecimento_razaoSocial               351495 non-null  object
#  16  estalecimento_noFantasia                  351495 non-null  object
#  17  estabelecimento_municipio_codigo          351495 non-null  int64
#  18  estabelecimento_municipio_nome            351495 non-null  object
#  19  estabelecimento_uf                        351495 non-null  object
#  20  vacina_grupoAtendimento_codigo            351482 non-null  float64
#  21  vacina_grupoAtendimento_nome              350516 non-null  object
#  22  vacina_categoria_codigo                   331099 non-null  float64
#  23  vacina_categoria_nome                     331099 non-null  object
#  24  vacina_lote                               351495 non-null  object
#  25  vacina_fabricante_nome                    351495 non-null  object
#  26  vacina_fabricante_referencia              349319 non-null  object
#  27  vacina_dataAplicacao                      351495 non-null  object
#  28  vacina_descricao_dose                     351495 non-null  object
#  29  vacina_codigo                             351495 non-null  int64
#  30  vacina_nome                               351486 non-null  object
#  31  sistema_origem                            351096 non-null  object
# dtypes: float64(2), int64(5), object(25)
# memory usage: 85.8+ MB

# %% [markdown]
# ## Copiando parte do dataframe

# %%
vacAcre_copy = vacAcre[:20000].copy()
vacAcre_copy
# Out:
#                                      document_id  \
# 0      c5ec44e8-a007-43c3-93d1-45125a6a2548-i0b0
# 1      8a962569-8693-4c30-866f-4d3fba14a686-i0b0
# 2      fb5df3d7-a372-4ff1-a346-01963be6e51c-i0b0
# 3      8aacaae0-8920-4733-9824-8ca22147c6b9-i0b0
# 4      c4fe1c06-9d03-4fb3-9f09-d03ae04172ed-i0b0
# ...                                          ...
# 19995  6faf2012-85b4-40b5-85f8-6db03f85cd16-i0b0
# 19996  0d701c13-2740-4ba2-816f-b059a2dc5d15-i0b0
# 19997  c7777d40-f116-421e-82ad-ced2de746ffa-i0b0
# 19998  34b7ab22-cdda-4b05-a695-b246a910e822-i0b0
# 19999  f00ffebd-5bf6-4b9f-a579-5e0e4f72ea42-i0b0
#
#                                              paciente_id  paciente_idade  \
# 0      27ee28eed45c4a09ef3a63f87dec8d43ed5c95812d7c31...              19
# 1      6f7639d85ae7378350820fc380218065678f2b8c6afae6...              29
# 2      a32b116a1c8cfab56a0e4c972c35289d89ea9995ed89c5...              40
# 3      bd90a92321a8c2899e9fd1ed54f2a72f3d485ca0cba91c...              12
# 4      b04dc8dc9a414410e7defb82eedd78ffeba9326ffe2a5e...              14
# ...                                                  ...             ...
# 19995  8b8fa1ce6459fd0a1ccd193d94125edd6a03b023399a2b...              27
# 19996  9910d9fd57ac7600fe9b2075cb7abebdbdf2238b86c2b3...              25
# 19997  5a80b384bd70630d9e2d4cd03ab73756cde9b302443ff3...              26
# 19998  28db499cce51a4cd10349d133cb240bf818706f2310f4b...              80
# 19999  5acd88488305039275be84568a6ae650a2f3622780fe5f...              46
#
#       paciente_dataNascimento paciente_enumSexoBiologico  \
# 0                  2002-05-08                          F
# 1                  1992-06-21                          M
# 2                  1980-10-06                          F
# 3                  2010-03-01                          M
# 4                  2007-04-05                          F
# ...                       ...                        ...
# 19995              1994-05-28                          F
# 19996              1996-04-20                          M
# 19997              1995-10-02                          F
# 19998              1940-04-03                          F
# 19999              1974-11-20                          M
#
#        paciente_racaCor_codigo paciente_racaCor_valor  \
# 0                           99         SEM INFORMACAO
# 1                           99         SEM INFORMACAO
# 2                            3                  PARDA
# 3                            5               INDIGENA
# 4                           99         SEM INFORMACAO
# ...                        ...                    ...
# 19995                        3                  PARDA
# 19996                        4                AMARELA
# 19997                        4                AMARELA
# 19998                        4                AMARELA
# 19999                        3                  PARDA
#
#       paciente_endereco_coIbgeMunicipio paciente_endereco_coPais  \
# 0                              120040.0                     10.0
# 1                              120032.0                     10.0
# 2                              120040.0                     10.0
# 3                              120043.0                     10.0
# 4                              120040.0                     10.0
# ...                                 ...                      ...
# 19995                          120040.0                     10.0
# 19996                          120050.0                     10.0
# 19997                          120040.0                     10.0
# 19998                               NaN                      NaN
# 19999                          120040.0                     10.0
#
#       paciente_endereco_nmMunicipio  ... vacina_categoria_codigo  \
# 0                        RIO BRANCO  ...                     2.0
# 1                            JORDAO  ...                     2.0
# 2                        RIO BRANCO  ...                     9.0
# 3               SANTA ROSA DO PURUS  ...                     7.0
# 4                        RIO BRANCO  ...                     2.0
# ...                             ...  ...                     ...
# 19995                    RIO BRANCO  ...                     2.0
# 19996                SENA MADUREIRA  ...                     2.0
# 19997                    RIO BRANCO  ...                     2.0
# 19998                           NaN  ...                     2.0
# 19999                    RIO BRANCO  ...                     2.0
#
#         vacina_categoria_nome vacina_lote vacina_fabricante_nome  \
# 0                Faixa Etária      FA9096                 PFIZER
# 1                Faixa Etária  215VCD134Z    ASTRAZENECA/FIOCRUZ
# 2      Trabalhadores de Saúde   202010040       SINOVAC/BUTANTAN
# 3             Povos Indígenas      FP8073                 PFIZER
# 4                Faixa Etária      FA9096                 PFIZER
# ...                       ...         ...                    ...
# 19995            Faixa Etária      FF8848                 PFIZER
# 19996            Faixa Etária     208A21A                JANSSEN
# 19997            Faixa Etária      FM3809                 PFIZER
# 19998            Faixa Etária     210052A       SINOVAC/BUTANTAN
# 19999            Faixa Etária  216VCD203Z    ASTRAZENECA/FIOCRUZ
#
#        vacina_fabricante_referencia vacina_dataAplicacao  \
# 0       Organization/00394544000851           2021-07-23
# 1       Organization/33781055000135           2021-07-21
# 2       Organization/61189445000156           2021-02-24
# 3                Organization/28290           2022-03-28
# 4       Organization/00394544000851           2021-08-11
# ...                             ...                  ...
# 19995   Organization/00394544000851           2021-10-19
# 19996   Organization/00394544000851           2021-07-02
# 19997            Organization/28290           2021-12-22
# 19998   Organization/61189445000156           2021-03-19
# 19999   Organization/33781055000135           2021-08-02
#
#       vacina_descricao_dose  vacina_codigo  \
# 0                   1ª Dose             87
# 1                   1ª Dose             85
# 2                   2ª Dose             86
# 3                   1ª Dose             87
# 4                   1ª Dose             87
# ...                     ...            ...
# 19995               2ª Dose             87
# 19996                  Dose             88
# 19997               2ª Dose             87
# 19998               2ª Dose             86
# 19999               2ª Dose             85
#
#                                      vacina_nome sistema_origem
# 0                    COVID-19 PFIZER - COMIRNATY       Novo PNI
# 1      COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 2          COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# 3                    COVID-19 PFIZER - COMIRNATY       Novo PNI
# 4                    COVID-19 PFIZER - COMIRNATY       Novo PNI
# ...                                          ...            ...
# 19995                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 19996             COVID-19 JANSSEN - Ad26.COV2.S       Novo PNI
# 19997                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 19998      COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# 19999  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
#
# [20000 rows x 32 columns]

# %% [markdown]
# ## Qual o percentual das vacinas aplicadas foram na capital???

# %%
vacAcre_copy['fl_capital'] = 0

# %%
vacAcre_copy.head(2)
# Out:
#                                  document_id  \
# 0  c5ec44e8-a007-43c3-93d1-45125a6a2548-i0b0
# 1  8a962569-8693-4c30-866f-4d3fba14a686-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  27ee28eed45c4a09ef3a63f87dec8d43ed5c95812d7c31...              19
# 1  6f7639d85ae7378350820fc380218065678f2b8c6afae6...              29
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              2002-05-08                          F                       99
# 1              1992-06-21                          M                       99
#
#   paciente_racaCor_valor paciente_endereco_coIbgeMunicipio  \
# 0         SEM INFORMACAO                          120040.0
# 1         SEM INFORMACAO                          120032.0
#
#   paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                     10.0                    RIO BRANCO  ...
# 1                     10.0                        JORDAO  ...
#
#   vacina_categoria_nome vacina_lote vacina_fabricante_nome  \
# 0          Faixa Etária      FA9096                 PFIZER
# 1          Faixa Etária  215VCD134Z    ASTRAZENECA/FIOCRUZ
#
#   vacina_fabricante_referencia  vacina_dataAplicacao vacina_descricao_dose  \
# 0  Organization/00394544000851            2021-07-23               1ª Dose
# 1  Organization/33781055000135            2021-07-21               1ª Dose
#
#   vacina_codigo                                vacina_nome sistema_origem  \
# 0            87                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 1            85  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
#
#   fl_capital
# 0          0
# 1          0
#
# [2 rows x 33 columns]

# %%
vacAcre_copy.loc[vacAcre_copy['paciente_endereco_nmMunicipio'] == 'RIO BRANCO', 'fl_capital'] = 1

# %%
vacAcre_copy.head(10)
# Out:
#                                  document_id  \
# 0  b19cd280-474c-4c22-a35d-8c06bc04a4e0-i0b0
# 1  d7e13d32-32fb-4e9a-a559-b0bdd7929d2b-i0b0
# 2  af279a98-ba1f-47ea-8214-314a98040b0d-i0b0
# 3  22f523ac-3eb6-45b2-9f6e-4e9906f09b5a-i0b0
# 4  000e911b-e3a4-4114-a735-d1f2e6e3797f-i0b0
# 5  9035fd8d-e21e-43aa-95a8-892ddce06bda-i0b0
# 6  852365aa-108b-4aa2-ae39-7b5d46149678-i0b0
# 7  ae1c0b6b-bebd-4c4d-ad20-e93fe3b298bd-i0b0
# 8  005c7f34-2539-4d3a-895d-60abdd1dde10-i0b0
# 9  cbd365c9-a7c1-4adc-a668-f33663894c38-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  2e091c9a37d3f50d1d705fc80c6448c6fc69b44da9e936...              69
# 1  dd179041b80ce919ceffa504ad2eae6f9ac3d6bbdfd531...              63
# 2  6734b26bccf826130ebffa66575977bbe71477b12bcf42...              69
# 3  54dfc421baa6a03e54c8a57f08c50b0281d40659849fbc...              19
# 4  c59571e19f368d4b0cf08cd3bcabb32e5cd8baad5340f6...              65
# 5  911e0352836d332b794dc70a6d5def479d66299d4e5bf4...              66
# 6  33950e1cfc224c872655e817922f304e87ffae6e049363...              65
# 7  88060b117766354835226675e2d980ff7afb64b0d895a3...              82
# 8  7988b2c4524d3475c8f14dfba74b3027569920f7499dac...              79
# 9  4114f08669a233367d79524c66a34ca3d09a9dbbb67a46...              47
#
#   paciente_datanascimento paciente_enumsexobiologico  paciente_racacor_codigo  \
# 0              1951-12-28                          F                        3
# 1              1957-06-09                          M                        3
# 2              1951-08-14                          M                        4
# 3              2001-04-28                          M                        5
# 4              1955-11-21                          M                        3
# 5              1955-04-01                          F                        4
# 6              1955-09-25                          M                        4
# 7              1938-05-09                          F                        4
# 8              1941-06-10                          F                        5
# 9              1973-09-07                          F                        5
#
#   paciente_racacor_valor  paciente_endereco_coibgemunicipio  \
# 0                  PARDA                           120050.0
# 1                  PARDA                           120040.0
# 2                AMARELA                           120020.0
# 3               INDIGENA                           120033.0
# 4                  PARDA                           120040.0
# 5                AMARELA                           320500.0
# 6                AMARELA                           120050.0
# 7                AMARELA                           120040.0
# 8               INDIGENA                           120005.0
# 9               INDIGENA                           120005.0
#
#    paciente_endereco_copais paciente_endereco_nmmunicipio  ...  \
# 0                      10.0                SENA MADUREIRA  ...
# 1                      10.0                    RIO BRANCO  ...
# 2                      10.0               CRUZEIRO DO SUL  ...
# 3                      10.0                   MANCIO LIMA  ...
# 4                      10.0                    RIO BRANCO  ...
# 5                      10.0                         SERRA  ...
# 6                      10.0                SENA MADUREIRA  ...
# 7                      10.0                    RIO BRANCO  ...
# 8                      10.0                  ASSIS BRASIL  ...
# 9                      10.0                  ASSIS BRASIL  ...
#
#   vacina_fabricante_nome vacina_fabricante_referencia  vacina_dataaplicacao  \
# 0      FUNDACAO BUTANTAN  Organization/61189445000156            2021-03-23
# 1      FUNDACAO BUTANTAN  Organization/61189445000156            2021-04-28
# 2      FUNDACAO BUTANTAN  Organization/61189445000156            2021-04-16
# 3      FUNDACAO BUTANTAN  Organization/61189445000156            2021-03-02
# 4  FUNDACAO OSWALDO CRUZ  Organization/33781055000135            2021-03-29
# 5      FUNDACAO BUTANTAN  Organization/61189445000156            2021-04-29
# 6  FUNDACAO OSWALDO CRUZ  Organization/33781055000135            2021-03-30
# 7      FUNDACAO BUTANTAN  Organization/61189445000156            2021-04-14
# 8      FUNDACAO BUTANTAN  Organization/61189445000156            2021-01-29
# 9      FUNDACAO BUTANTAN  Organization/61189445000156            2021-02-06
#
#   vacina_descricao_dose  vacina_codigo                          vacina_nome  \
# 0               1ª Dose             86  Covid-19-Coronavac-Sinovac/Butantan
# 1               2ª Dose             86  Covid-19-Coronavac-Sinovac/Butantan
# 2               1ª Dose             86  Covid-19-Coronavac-Sinovac/Butantan
# 3               2ª Dose             86  Covid-19-Coronavac-Sinovac/Butantan
# 4               1ª Dose             85         Vacina Covid-19 - Covishield
# 5               2ª Dose             86  Covid-19-Coronavac-Sinovac/Butantan
# 6               1ª Dose             85         Vacina Covid-19 - Covishield
# 7               2ª Dose             86  Covid-19-Coronavac-Sinovac/Butantan
# 8               1ª Dose             86  Covid-19-Coronavac-Sinovac/Butantan
# 9               2ª Dose             86  Covid-19-Coronavac-Sinovac/Butantan
#
#   sistema_origem      data_importacao_rnds id_sistema_origem fl_capital
# 0       Novo PNI  2021-03-25T03:27:19.000Z               NaN          0
# 1       Novo PNI  2021-05-02T15:41:55.000Z               NaN          1
# 2       Novo PNI  2021-04-16T15:54:39.000Z               NaN          0
# 3       Novo PNI  2021-03-22T20:21:06.000Z               NaN          0
# 4       Novo PNI  2021-04-03T19:44:28.000Z               NaN          1
# 5       Novo PNI  2021-05-01T16:44:35.000Z               NaN          0
# 6       Novo PNI  2021-04-06T16:34:46.000Z               NaN          0
# 7       Novo PNI  2021-04-30T14:26:06.000Z               NaN          1
# 8       Novo PNI  2021-02-05T22:52:20.000Z               NaN          0
# 9       Novo PNI  2021-02-17T11:48:41.000Z               NaN          0
#
# [10 rows x 35 columns]

# %%
vacAcre_copy[['paciente_endereco_nmMunicipio','fl_capital']]
# Out:
#       paciente_endereco_nmMunicipio  fl_capital
# 0                        RIO BRANCO           1
# 1                            JORDAO           0
# 2                        RIO BRANCO           1
# 3               SANTA ROSA DO PURUS           0
# 4                        RIO BRANCO           1
# ...                             ...         ...
# 19995                    RIO BRANCO           1
# 19996                SENA MADUREIRA           0
# 19997                    RIO BRANCO           1
# 19998                           NaN           0
# 19999                    RIO BRANCO           1
#
# [20000 rows x 2 columns]

# %%
vacAcre_copy['fl_capital'].sum()
# Out:
# 9891

# %%
9294/20000
# Out:
# 0.4647

# %% [markdown]
# ## Qual a idade média dos pacientes???

# %%
vacAcre_copy['paciente_idade'].mean()
# Out:
# 36.7017
